# %%
# %load_ext autoreload
# %autoreload 2

import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

try:
    import text_recognizer
except ImportError:
    import sys
    sys.path.append('..')

from text_recognizer.datasets import IamDataset
from text_recognizer.datasets import IamParagraphsDataset

# %%
dataset = IamDataset()
print(dataset)
# Out:
# IAM Dataset
# Num forms: 1539

# %%
paragraphs_dataset = IamParagraphsDataset()
paragraphs_dataset.load_or_generate_data()
print(paragraphs_dataset)
# Out:
# Max crop width and height were found to be 1240x1156.
# Setting them to 1240x1240
# Cropping paragraphs, generating ground truth, and saving debugging images to /home/pagpires/PROJECT/fsdl-text-recognizer-project/data/interim/iam_paragraphs/debug_crops
# Rescued /home/pagpires/PROJECT/fsdl-text-recognizer-project/data/raw/iam/iamdb/forms/e01-086.jpg: could not broadcast input array from shape (687,1236) into shape (687,1240)
# Rescued /home/pagpires/PROJECT/fsdl-text-recognizer-project/data/raw/iam/iamdb/forms/e01-081.jpg: could not broadcast input array from shape (587,1236) into shape (587,1240)
# Loading IAM paragraph crops and ground truth from image files...
# IAM Paragraphs Dataset
# Num classes: 3
# Train: (1229, 256, 256) (1229, 256, 256, 3)
# Test: (308, 256, 256) (308, 256, 256, 3)

# %%
for ind in range(10):
    x = paragraphs_dataset.x_train[ind]
    y = paragraphs_dataset.y_train[ind]
    fig = plt.figure(figsize=(10,5))
    ax1 = fig.add_subplot(121)
    ax1.matshow(x, cmap='gray')
    ax2 = fig.add_subplot(122)
    ax2.matshow(y.argmax(-1), cmap='gray')
